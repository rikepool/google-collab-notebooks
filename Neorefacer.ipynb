# %% [markdown]
# Follow me on Instagram : https://www.instagram.com/xsocialandapps/
#
# Run without installation (GPU): https://buymeacoffee.com/socialadapps/e/397433
#
# Run without installation (CPU): https://buymeacoffee.com/socialadapps/e/397334

# %% [markdown]
# # #1 Clone

# %%
# %cd /content
# !git clone https://github.com/MechasAI/NeoRefacer.git
# %cd /content/NeoRefacer

# %% [markdown]
# # #2 Requiremets

# %%
# !pip install ffmpeg_python==0.2.0
# !pip install imageio[ffmpeg]==2.37.0
# !pip install imagecodecs==2025.3.30
# !pip install gradio==5.22.0
# !pip install insightface==0.7.3
# !pip install --upgrade --force-reinstall numpy==2.0.1
# !pip install onnx==1.16.2
# !pip install onnxruntime-gpu==1.20.0
# !pip install opencv_python==4.7.0.72
# !pip install --upgrade --force-reinstall opencv-python-headless==4.12.0.88
# !pip install --upgrade scikit-image
# !pip install tqdm==4.67.1
# !pip install psutil==7.0.0
# !pip install ngrok==1.4.0
# !pip install pyfiglet==1.0.2
# codeformer dependencies
# torch==2.6.0
# torchvision==0.21.0
# !pip install gdown==5.2.0
# !pip install lpips==0.1.4

# %% [markdown]
# # #3 Main Code

# %%
# !python app.py --share_gradio
