# %% [markdown]
# ![2025-07-17_00h01_30.png](data:image/png;base64,...)

# %% [markdown]
# # Follow my Instagram : https://www.instagram.com/xsocialandapps/
# # Portable tools : https://buymeacoffee.com/socialadapps

# %%
# %cd /content
# !git clone https://github.com/deepbeepmeep/Wan2GP.git
# %cd Wan2GP
# !pip install torch==2.6.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/test/cu124
# !pip install -r requirements.txt

# %%
# Replace 'TkAgg' with 'Agg' programmatically
file_path = "/content/Wan2GP/preprocessing/matanyone/tools/interact_tools.py"

with open(file_path, "r") as file:
    content = file.read()

content = content.replace("matplotlib.use('TkAgg')", "matplotlib.use('Agg')")

with open(file_path, "w") as file:
    file.write(content)

print("✅ Backend fixed to 'Agg' for headless environment.")

# %%
# !python wgp.py --share

# %%
# !nvidia-smi
