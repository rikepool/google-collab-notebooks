# %% [markdown]
# Follow my Instagram : https://www.instagram.com/xsocialandapps/
#
# Portable tools : https://buymeacoffee.com/socialadapps

# %% [markdown]
# # Clone

# %%
# %cd /content
# !git lfs install
# !git clone https://github.com/index-tts/index-tts.git
# %cd index-tts

# %% [markdown]
# # Download models

# %%
# !huggingface-cli download IndexTeam/IndexTTS-2 --local-dir /content/index-tts/checkpoints

# %% [markdown]
# # Pytorch Install

# %%
# !pip install torch==2.8.0+cu128 torchaudio==2.8.0+cu128 \
    --index-url https://download.pytorch.org/whl/cu128

# %% [markdown]
# # Requirements

# %%
# Install core dependencies
# !pip install \
    accelerate==1.8.1 \
    cn2an==0.5.22 \
    cython==3.0.7 \
    deepspeed==0.17.1 \
    descript-audiotools==0.7.2 \
    ffmpeg-python==0.2.0 \
    g2p-en==2.1.0 \
    jieba==0.42.1 \
    json5==0.10.0 \
    keras==2.9.0 \
    librosa==0.10.2.post1 \
    matplotlib==3.8.2 \
    modelscope==1.27.0 \
    munch==4.0.0 \
    numba==0.58.1 \
    numpy==1.26.2 \
    omegaconf>=2.3.0 \
    opencv-python==4.9.0.80 \
    pandas==2.3.2 \
    safetensors==0.5.2 \
    sentencepiece>=0.2.1 \
    tensorboard==2.9.1 \
    textstat>=0.7.10 \
    tokenizers==0.21.0 \
    tqdm>=4.67.1 \
    transformers==4.52.1

# Platform-specific deps
import sys
if sys.platform == "linux":
    # !pip install WeTextProcessing
else:
    # !pip install wetext>=0.0.9

# Optional WebUI
# !pip install gradio>=5.44.1

# %% [markdown]
# # Requirements #2

# %%
# !pip install \
    accelerate==1.8.1 \
    cn2an==0.5.22 \
    cython==3.0.7 \
    deepspeed==0.17.1 \
    descript-audiotools==0.7.2 \
    ffmpeg-python==0.2.0 \
    g2p-en==2.1.0 \
    jieba==0.42.1 \
    json5==0.10.0 \
    keras==2.9.0 \
    librosa==0.10.2.post1 \
    matplotlib==3.8.2 \
    modelscope==1.27.0 \
    munch==4.0.0 \
    numba==0.58.1 \
    numpy==1.26.2 \
    omegaconf>=2.3.0 \
    opencv-python==4.9.0.80 \
    pandas==2.3.2 \
    safetensors==0.5.2 \
    sentencepiece>=0.2.1 \
    tensorboard==2.9.1 \
    textstat>=0.7.10 \
    tokenizers==0.21.0 \
    tqdm>=4.67.1 \
    transformers==4.52.1

# %% [markdown]
# # Requirements #3

# %%
# !pip install accelerate==1.8.1
# !pip install cn2an==0.5.22
# !pip install cython==3.0.7
# !pip install deepspeed==0.17.1
# !pip install descript-audiotools==0.7.2
# !pip install ffmpeg-python==0.2.0
# !pip install g2p-en==2.1.0
# !pip install jieba==0.42.1
# !pip install json5==0.10.0
# !pip install librosa==0.10.2.post1
# !pip install matplotlib==3.8.2
# !pip install modelscope==1.27.0
# !pip install munch==4.0.0
# !pip install numba==0.58.1
# !pip install numpy==1.26.2
# !pip install omegaconf>=2.3.0
# !pip install opencv-python==4.9.0.80
# !pip install pandas==2.3.2
# !pip install safetensors==0.5.2
# !pip install sentencepiece>=0.2.1
# !pip install tensorboard==2.9.1
# !pip install textstat>=0.7.10
# !pip install tokenizers==0.21.0
# !pip install tqdm>=4.67.1
# !pip install transformers==4.52.1

# Step 3: Install wetext instead of WeTextProcessing (workaround)
# !pip install wetext>=0.0.9

# Step 4: Optional WebUI
# !pip install gradio>=5.44.1

# %% [markdown]
# # Fixing Python Error

# %%
# !pip install protobuf==3.20.3

# %% [markdown]
# # Main Code

# %%
# !python webui.py
